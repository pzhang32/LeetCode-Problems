# %% [markdown]
# You are given two strings s and t.
#
# String t is generated by random shuffling string s and then add one more letter at a random position.
#
# Return the letter that was added to t.
#
#
#
# Example 1:
#
# Input: s = "abcd", t = "abcde"
# Output: "e"
# Explanation: 'e' is the letter that was added.
# Example 2:
#
# Input: s = "", t = "y"
# Output: "y"

# %% [markdown]
# my solution, runtime 41ms, memory 16.55mb

# %%
class Solution:
    def findTheDifference(self, s: str, t: str) -> str:
        dic1 = {}
        for sub_s in s:
            if sub_s not in dic1:
                dic1[sub_s] = 1
            else:
                dic1[sub_s] += 1

        for sub_t in t:
            if sub_t not in dic1:
                return sub_t
            else:
                dic1[sub_t] -= 1
        for key in dic1:
            if dic1[key] == -1:
                return key
